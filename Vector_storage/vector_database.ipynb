# %%
! pip install langchain chromadb tiktoken
# Out:
# ...
#   Using cached chromadb-1.5.9-cp39-abi3-win_amd64.whl.metadata (5.1 kB)
# ...
#   Using cached build-1.5.0-py3-none-any.whl.metadata (5.7 kB)
# ...
#   Using cached opentelemetry_api-1.44.0-py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached grpcio-1.83.0-cp311-cp311-win_amd64.whl.metadata (3.8 kB)
# ...
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# ...
#   Using cached watchfiles-1.2.0-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# ...
#    ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#    -- ------------------------------------- 1.3/23.5 MB 9.5 MB/s eta 0:00:03
#    ----- ---------------------------------- 3.4/23.5 MB 8.0 MB/s eta 0:00:03
#    --------- ------------------------------ 5.8/23.5 MB 9.3 MB/s eta 0:00:02
#    ------------- -------------------------- 8.1/23.5 MB 9.9 MB/s eta 0:00:02
#    ------------------ --------------------- 10.7/23.5 MB 10.2 MB/s eta 0:00:02
# ...

# %%
! pip install langchain-chroma

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma

# %%
from langchain_core.documents import Document

# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs=[doc1,doc2,doc3,doc4,doc5]

# %%
vector_store=Chroma(
    embedding_function=HuggingFaceEmbeddings(),
    persist_directory='my_chroma_db',
    collection_name='sample'

)
# Out:
# ...
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 3770.42it/s]

# %%
vector_store.add_documents(docs)
# Out:
# ['302d0bb2-6a33-466a-904c-9231ceea1257',
#  '4b36d0f6-04b5-4ba6-9f16-12b14bff172d',
#  'ec87441a-c65b-4c50-ace3-5cd051f533bc',
#  '14fff306-1925-4035-bc69-44fed21e67b9',
#  '67c0b996-f149-4095-95dc-636df067cef4']

# %%
vector_store.get(include=['embeddings','documents','metadatas'])
# Out:
# {'ids': ['06125053-e47c-49d6-a494-115befdea302',
#   'e85b5a08-59a2-4a25-bd09-ed3898060428',
#   '1cee3e74-58b1-4210-b3ad-1308a7d89f9b',
#   'c93a605f-27ea-47cd-8003-8706d6513a5c',
#   'c32a6fd7-9869-47f3-9d1a-d754451c1f8e',
#   '302d0bb2-6a33-466a-904c-9231ceea1257',
#   '4b36d0f6-04b5-4ba6-9f16-12b14bff172d',
#   'ec87441a-c65b-4c50-ace3-5cd051f533bc',
#   '14fff306-1925-4035-bc69-44fed21e67b9',
#   '67c0b996-f149-4095-95dc-636df067cef4'],
#  'embeddings': array([[-0.03964759, -0.00801653, -0.01412727, ...,  0.06814156,
#          -0.00116096, -0.02425422],
#         [-0.01992604,  0.00161878, -0.00959345, ...,  0.02433112,
#          -0.00341396, -0.01722029],
#         [-0.04256175,  0.0106033 , -0.01305767, ...,  0.04738371,
#          -0.01748697,  0.00204662],
#         ...,
#         [-0.04256175,  0.0106033 , -0.01305767, ...,  0.04738371,
#          -0.01748697,  0.00204662],
#         [-0.02734399, -0.03300866,  0.01565382, ...,  0.01462706,
# ...

# %%
vector_store.similarity_search(
    query='who among these is best batsman?',
    k=3
)
# Out:
# [Document(id='06125053-e47c-49d6-a494-115befdea302', metadata={'team': 'Royal Challengers Bangalore'}, page_content='Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.'),
#  Document(id='302d0bb2-6a33-466a-904c-9231ceea1257', metadata={'team': 'Royal Challengers Bangalore'}, page_content='Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.'),
#  Document(id='ec87441a-c65b-4c50-ace3-5cd051f533bc', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.')]

# %%
vector_store.similarity_search_with_score(
    query='',
    filter={"team":'Chennai Super Kings'}
)
# Out:
# [(Document(id='1cee3e74-58b1-4210-b3ad-1308a7d89f9b', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   1.887957215309143),
#  (Document(id='ec87441a-c65b-4c50-ace3-5cd051f533bc', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   1.887957215309143),
#  (Document(id='c32a6fd7-9869-47f3-9d1a-d754451c1f8e', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   2.0017189979553223),
# ...

# %%
updated_doc1=Document(
    page_content="virat kohli , the former captin of Royal challengers ",
    metadata={"team":"Royal Challengers Bangalore"}
)
vector_store.update_document(document_id='06125053-e47c-49d6-a494-115befdea302',document=updated_doc1)

# %%
vector_store.get(include=['embeddings','documents','metadatas'])
# Out:
# {'ids': ['06125053-e47c-49d6-a494-115befdea302',
#   'e85b5a08-59a2-4a25-bd09-ed3898060428',
#   '1cee3e74-58b1-4210-b3ad-1308a7d89f9b',
#   'c93a605f-27ea-47cd-8003-8706d6513a5c',
#   'c32a6fd7-9869-47f3-9d1a-d754451c1f8e',
#   '302d0bb2-6a33-466a-904c-9231ceea1257',
#   '4b36d0f6-04b5-4ba6-9f16-12b14bff172d',
#   'ec87441a-c65b-4c50-ace3-5cd051f533bc',
#   '14fff306-1925-4035-bc69-44fed21e67b9',
#   '67c0b996-f149-4095-95dc-636df067cef4'],
#  'embeddings': array([[ 0.00431439, -0.01423772, -0.02242017, ..., -0.00704181,
#          -0.05127369, -0.01481952],
#         [-0.01992604,  0.00161878, -0.00959345, ...,  0.02433112,
#          -0.00341396, -0.01722029],
#         [-0.04256175,  0.0106033 , -0.01305767, ...,  0.04738371,
#          -0.01748697,  0.00204662],
#         ...,
#         [-0.04256175,  0.0106033 , -0.01305767, ...,  0.04738371,
#          -0.01748697,  0.00204662],
#         [-0.02734399, -0.03300866,  0.01565382, ...,  0.01462706,
# ...

# %%
vector_store.delete(ids=['06125053-e47c-49d6-a494-115befdea302'])

# %%
vector_store.get(include=['embeddings','documents','metadatas'])
# Out:
# {'ids': ['e85b5a08-59a2-4a25-bd09-ed3898060428',
#   '1cee3e74-58b1-4210-b3ad-1308a7d89f9b',
#   'c93a605f-27ea-47cd-8003-8706d6513a5c',
#   'c32a6fd7-9869-47f3-9d1a-d754451c1f8e',
#   '302d0bb2-6a33-466a-904c-9231ceea1257',
#   '4b36d0f6-04b5-4ba6-9f16-12b14bff172d',
#   'ec87441a-c65b-4c50-ace3-5cd051f533bc',
#   '14fff306-1925-4035-bc69-44fed21e67b9',
#   '67c0b996-f149-4095-95dc-636df067cef4'],
#  'embeddings': array([[-0.01992604,  0.00161878, -0.00959345, ...,  0.02433112,
#          -0.00341396, -0.01722029],
#         [-0.04256175,  0.0106033 , -0.01305767, ...,  0.04738371,
#          -0.01748697,  0.00204662],
#         [-0.02734399, -0.03300866,  0.01565382, ...,  0.01462706,
#           0.01177984,  0.00556418],
#         ...,
#         [-0.04256175,  0.0106033 , -0.01305767, ...,  0.04738371,
#          -0.01748697,  0.00204662],
#         [-0.02734399, -0.03300866,  0.01565382, ...,  0.01462706,
#           0.01177984,  0.00556418],
# ...
